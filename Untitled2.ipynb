# %% [markdown]
# XOR GATE

# %%
import tensorflow as tf
import time

x_ = tf.placeholder(tf.float32, shape=[4,2], name = 'x-input')
y_ = tf.placeholder(tf.float32, shape=[4,1], name = 'y-input')

Theta1 = tf.Variable(tf.random_uniform([2,2], -1, 1), name = "Theta1")
Theta2 = tf.Variable(tf.random_uniform([2,1], -1, 1), name = "Theta2")

Bias1 = tf.Variable(tf.zeros([2]), name = "Bias1")
Bias2 = tf.Variable(tf.zeros([1]), name = "Bias2")

with tf.name_scope("layer2") as scope:
    A2 = tf.sigmoid(tf.matmul(x_, Theta1) + Bias1)

with tf.name_scope("layer3") as scope:
    Hypothesis = tf.sigmoid(tf.matmul(A2, Theta2) + Bias2)

with tf.name_scope("cost") as scope:
    cost = tf.reduce_mean(( (y_ * tf.log(Hypothesis)) + 
        ((1 - y_) * tf.log(1.0 - Hypothesis)) ) * -1)

with tf.name_scope("train") as scope:
    train_step = tf.train.GradientDescentOptimizer(0.01).minimize(cost)

## For other gates change the input and output that is the value of X and Y.
XOR_X = [[0,0],[0,1],[1,0],[1,1]]
XOR_Y = [[0],[1],[1],[0]]

init = tf.initialize_all_variables()
sess = tf.Session()

writer = tf.summary.FileWriter("./logs/xor_logs11", sess.graph_def)
sess.run(init)

t_start = time.clock()
for i in range(100000):

    sess.run(train_step, feed_dict={x_: XOR_X, y_: XOR_Y})
    if i % 1000 == 0:

        print('Epoch ', i)
        print('Hypothesis ', sess.run(Hypothesis, feed_dict={x_: XOR_X, y_: XOR_Y}))
        print('Theta1 ', sess.run(Theta1))
        print('Bias1 ', sess.run(Bias1))
        print('Theta2 ', sess.run(Theta2))
        print('Bias2 ', sess.run(Bias2))
        print('cost ', sess.run(cost, feed_dict={x_: XOR_X, y_: XOR_Y}))

t_end = time.clock()
print('Elapsed time ', t_end - t_start)
# Out:
# WARNING:tensorflow:From /Anaconda/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_should_use.py:170: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# WARNING:tensorflow:Passing a `GraphDef` to the SummaryWriter is deprecated. Pass a `Graph` object instead, such as `sess.graph`.
# Epoch  0
# Hypothesis  [[ 0.41357249]
#  [ 0.43486831]
#  [ 0.38890132]
#  [ 0.40950546]]
# Theta1  [[ 0.64049441  0.79324114]
#  [-0.55237985 -0.73752445]]
# Bias1  [ -1.39160373e-04   2.09651698e-05]
# Theta2  [[-0.87060052]
#  [ 0.17033303]]
# Bias2  [ 0.00088628]
# cost  0.709411
# Epoch  1000
# Hypothesis  [[ 0.49952969]
#  [ 0.51141167]
#  [ 0.48483458]
#  [ 0.49648285]]
# Theta1  [[ 0.63270915  0.79003465]
#  [-0.54913741 -0.74380761]]
# Bias1  [-0.0031369  -0.00996645]
# Theta2  [[-0.74737698]
#  [ 0.29588509]]
# Bias2  [ 0.22401592]
# ...

# %% [markdown]
# AND GATE

# %%
import tensorflow as tf
import time

x_ = tf.placeholder(tf.float32, shape=[4,2], name = 'x-input')
y_ = tf.placeholder(tf.float32, shape=[4,1], name = 'y-input')

Theta1 = tf.Variable(tf.random_uniform([2,2], -1, 1), name = "Theta1")
Theta2 = tf.Variable(tf.random_uniform([2,1], -1, 1), name = "Theta2")

Bias1 = tf.Variable(tf.zeros([2]), name = "Bias1")
Bias2 = tf.Variable(tf.zeros([1]), name = "Bias2")

with tf.name_scope("layer2") as scope:
    A2 = tf.sigmoid(tf.matmul(x_, Theta1) + Bias1)

with tf.name_scope("layer3") as scope:
    Hypothesis = tf.sigmoid(tf.matmul(A2, Theta2) + Bias2)

with tf.name_scope("cost") as scope:
    cost = tf.reduce_mean(( (y_ * tf.log(Hypothesis)) + 
        ((1 - y_) * tf.log(1.0 - Hypothesis)) ) * -1)

with tf.name_scope("train") as scope:
    train_step = tf.train.GradientDescentOptimizer(0.01).minimize(cost)

## For other gates change the input and output that is the value of X and Y.
AND_X = [[0,0],[0,1],[1,0],[1,1]]
AND_Y = [[0],[0],[0],[1]]

init = tf.initialize_all_variables()
sess = tf.Session()

writer = tf.summary.FileWriter("./logs/xor_logs12", sess.graph_def)
sess.run(init)

t_start = time.clock()
for i in range(29000):

    sess.run(train_step, feed_dict={x_: AND_X, y_: AND_Y})
    if i % 1000 == 0:

        print('Epoch ', i)
        print('Hypothesis ', sess.run(Hypothesis, feed_dict={x_: AND_X, y_: AND_Y}))
        print('Theta1 ', sess.run(Theta1))
        print('Bias1 ', sess.run(Bias1))
        print('Theta2 ', sess.run(Theta2))
        print('Bias2 ', sess.run(Bias2))
        print('cost ', sess.run(cost, feed_dict={x_: AND_X, y_: AND_Y}))

t_end = time.clock()
print('Elapsed time ', t_end - t_start)
# Out:
# WARNING:tensorflow:From /Anaconda/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_should_use.py:170: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# WARNING:tensorflow:Passing a `GraphDef` to the SummaryWriter is deprecated. Pass a `Graph` object instead, such as `sess.graph`.
# Epoch  0
# Hypothesis  [[ 0.4650172 ]
#  [ 0.4626078 ]
#  [ 0.46266645]
#  [ 0.46022028]]
# Theta1  [[ 0.44936177  0.34345034]
#  [-0.39156714 -0.21127875]]
# Bias1  [-0.00028029  0.00043158]
# Theta2  [[ 0.54964894]
#  [-0.82544506]]
# Bias2  [-0.00213457]
# cost  0.660933
# Epoch  1000
# Hypothesis  [[ 0.25081384]
#  [ 0.27211198]
#  [ 0.25339112]
#  [ 0.27493742]]
# Theta1  [[ 0.53084326  0.08301064]
#  [-0.31348833 -0.45867431]]
# Bias1  [-0.0562731   0.14263369]
# Theta2  [[ 0.28817579]
#  [-1.16385543]]
# Bias2  [-0.61095262]
# cost  0.54745
# ...

# %% [markdown]
# NAND GATE

# %%
import tensorflow as tf
import time

x_ = tf.placeholder(tf.float32, shape=[4,2], name = 'x-input')
y_ = tf.placeholder(tf.float32, shape=[4,1], name = 'y-input')

Theta1 = tf.Variable(tf.random_uniform([2,2], -1, 1), name = "Theta1")
Theta2 = tf.Variable(tf.random_uniform([2,1], -1, 1), name = "Theta2")

Bias1 = tf.Variable(tf.zeros([2]), name = "Bias1")
Bias2 = tf.Variable(tf.zeros([1]), name = "Bias2")

with tf.name_scope("layer2") as scope:
    A2 = tf.sigmoid(tf.matmul(x_, Theta1) + Bias1)

with tf.name_scope("layer3") as scope:
    Hypothesis = tf.sigmoid(tf.matmul(A2, Theta2) + Bias2)

with tf.name_scope("cost") as scope:
    cost = tf.reduce_mean(( (y_ * tf.log(Hypothesis)) + 
        ((1 - y_) * tf.log(1.0 - Hypothesis)) ) * -1)

with tf.name_scope("train") as scope:
    train_step = tf.train.GradientDescentOptimizer(0.01).minimize(cost)

## For other gates change the input and output that is the value of X and Y.
NAND_X = [[0,0],[0,1],[1,0],[1,1]]
NAND_Y = [[1],[1],[1],[0]]

init = tf.initialize_all_variables()
sess = tf.Session()

writer = tf.summary.FileWriter("./logs/xor_logs13", sess.graph_def)
sess.run(init)

t_start = time.clock()
for i in range(100000):

    sess.run(train_step, feed_dict={x_: NAND_X, y_: NAND_Y})
    if i % 1000 == 0:

        print('Epoch ', i)
        print('Hypothesis ', sess.run(Hypothesis, feed_dict={x_: NAND_X, y_: NAND_Y}))
        print('Theta1 ', sess.run(Theta1))
        print('Bias1 ', sess.run(Bias1))
        print('Theta2 ', sess.run(Theta2))
        print('Bias2 ', sess.run(Bias2))
        print('cost ', sess.run(cost, feed_dict={x_: NAND_X, y_: NAND_Y}))

t_end = time.clock()
print('Elapsed time ', t_end - t_start)
# Out:
# WARNING:tensorflow:From /Anaconda/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_should_use.py:170: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# WARNING:tensorflow:Passing a `GraphDef` to the SummaryWriter is deprecated. Pass a `Graph` object instead, such as `sess.graph`.
# Epoch  0
# Hypothesis  [[ 0.65465224]
#  [ 0.62536353]
#  [ 0.59560186]
#  [ 0.57299238]]
# Theta1  [[-0.88923031 -0.68279052]
#  [-0.57041228  0.07862811]]
# Bias1  [ 0.00040548  0.00010987]
# Theta2  [[ 0.96047038]
#  [ 0.31565517]]
# Bias2  [ 0.00138333]
# cost  0.565552
# Epoch  1000
# Hypothesis  [[ 0.81557065]
#  [ 0.77431625]
#  [ 0.73366159]
#  [ 0.69477314]]
# Theta1  [[-1.01345766 -0.79196995]
#  [-0.70113277 -0.03187538]]
# Bias1  [ 0.24219912  0.04925032]
# Theta2  [[ 1.4370327 ]
#  [ 0.64578736]]
# Bias2  [ 0.35067236]
# ...

# %% [markdown]
# OR GATE

# %%
import tensorflow as tf
import time

x_ = tf.placeholder(tf.float32, shape=[4,2], name = 'x-input')
y_ = tf.placeholder(tf.float32, shape=[4,1], name = 'y-input')

Theta1 = tf.Variable(tf.random_uniform([2,2], -1, 1), name = "Theta1")
Theta2 = tf.Variable(tf.random_uniform([2,1], -1, 1), name = "Theta2")

Bias1 = tf.Variable(tf.zeros([2]), name = "Bias1")
Bias2 = tf.Variable(tf.zeros([1]), name = "Bias2")

with tf.name_scope("layer2") as scope:
    A2 = tf.sigmoid(tf.matmul(x_, Theta1) + Bias1)

with tf.name_scope("layer3") as scope:
    Hypothesis = tf.sigmoid(tf.matmul(A2, Theta2) + Bias2)

with tf.name_scope("cost") as scope:
    cost = tf.reduce_mean(( (y_ * tf.log(Hypothesis)) + 
        ((1 - y_) * tf.log(1.0 - Hypothesis)) ) * -1)

with tf.name_scope("train") as scope:
    train_step = tf.train.GradientDescentOptimizer(0.01).minimize(cost)

## For other gates change the input and output that is the value of X and Y.
OR_X = [[0,0],[0,1],[1,0],[1,1]]
OR_Y = [[0],[1],[1],[1]]

init = tf.initialize_all_variables()
sess = tf.Session()

writer = tf.summary.FileWriter("./logs/xor_logs14", sess.graph_def)
sess.run(init)

t_start = time.clock()
for i in range(100000):

    sess.run(train_step, feed_dict={x_: OR_X, y_: OR_Y})
    if i % 1000 == 0:

        print('Epoch ', i)
        print('Hypothesis ', sess.run(Hypothesis, feed_dict={x_: OR_X, y_: OR_Y}))
        print('Theta1 ', sess.run(Theta1))
        print('Bias1 ', sess.run(Bias1))
        print('Theta2 ', sess.run(Theta2))
        print('Bias2 ', sess.run(Bias2))
        print('cost ', sess.run(cost, feed_dict={x_: OR_X, y_: OR_Y}))

t_end = time.clock()
print('Elapsed time ', t_end - t_start)
# Out:
# WARNING:tensorflow:From /Anaconda/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_should_use.py:170: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# WARNING:tensorflow:Passing a `GraphDef` to the SummaryWriter is deprecated. Pass a `Graph` object instead, such as `sess.graph`.
# Epoch  0
# Hypothesis  [[ 0.60996717]
#  [ 0.61986613]
#  [ 0.6512112 ]
#  [ 0.65529078]]
# Theta1  [[ 0.93664289  0.66579336]
#  [ 0.60305339 -0.59645772]]
# Bias1  [  8.13712177e-05   7.55441142e-05]
# Theta2  [[ 0.58724999]
#  [ 0.30473387]]
# Bias2  [ 0.00116452]
# cost  0.567843
# Epoch  1000
# Hypothesis  [[ 0.71833318]
#  [ 0.75217217]
#  [ 0.78774118]
#  [ 0.80361027]]
# Theta1  [[ 1.11412621  0.77941632]
#  [ 0.81337011 -0.47080469]]
# Bias1  [-0.08378942  0.00177903]
# Theta2  [[ 1.14433002]
#  [ 0.43135431]]
# Bias2  [ 0.17213129]
# ...
